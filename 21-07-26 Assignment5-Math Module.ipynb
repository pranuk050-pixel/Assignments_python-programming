# %% [markdown]
# Python Math Module – 30 Coding Questions

# %%
#1.Write a program to calculate the square root of a number using the math module.
num=25
import math
math.sqrt(num)
# Out:
# 5.0

# %%
#2.Find the cube root of a given number using mathematical operations.
num= int(input("enter a number"))
math.cbrt(num)
# Out:
# 8.549879733383484

# %%
#3.Calculate the factorial of a number using math.factorial().
num = 7
math.factorial(num)
# Out:
# 5040

# %%
#4.Find the GCD (Greatest Common Divisor) of two numbers using math.gcd().
x=20
y=30
math.gcd(x,y)
# Out:
# 10

# %%
#5.Find the LCM of two numbers using math.lcm().
x=20
y=30
math.lcm(x,y)
# Out:
# 60

# %%
#6.Calculate the value of 5 raised to the power of 8 using math.pow().
x=5
y=8
math.pow(x,y)
# Out:
# 390625.0

# %%
#7.Find the absolute value of a negative decimal number using math.fabs().
x=-10
math.fabs(x)
# Out:
# 10.0

# %%
#8.Round a floating-point number up using math.ceil().
x=20.562515423
math.ceil(x)
# Out:
# 21

# %%
#9.Round a floating-point number down using math.floor().
x=20.562515423
math.floor(x)
# Out:
# 20

# %%
#10.Round a floating-point number to the nearest integer using round().
x=20.562515423
round(x)
# Out:
# 21

# %%
#11.Find the remainder of two numbers using math.fmod().
x=25
y=10
math.fmod(x,y)
# Out:
# 5.0

# %%
#12.Find the quotient and remainder using divmod()
x=15
y=5
Q,R=(divmod(x,y))
print("Quotient is",Q)
print("Remainder is",R)
# Out:
# Quotient is 3
# Remainder is 0

# %%
#13.Calculate the sine, cosine, and tangent of 45 degrees.

degrees = 45
radians = math.radians(degrees)

sine = math.sin(radians)
cosine = math.cos(radians)
tangent = math.tan(radians)

print("sine:", sine)
print("cosine:", cosine)
print("tangent:", tangent)
# Out:
# sine: 0.7071067811865476
# cosine: 0.7071067811865476
# tangent: 0.9999999999999999

# %%
#14.Convert an angle from degrees to radians.
angel_in_degrees = 45
angel_in_radians = math.radians(angel_in_degrees)
print(angel_in_radians)
# Out:
# 0.7853981633974483

# %%
#15.Convert an angle from radians to degrees.
radians = 0.7853981633974483
degrees = math.degrees(radians)
print(degrees)
# Out:
# 45.0

# %%
#16.Find the logarithm (base 10) of a number using math.log10().
num=100
math.log10(num)
# Out:
# 2.0

# %%
#17.Find the natural logarithm of a number using math.log().
num=30
math.log(num)
# Out:
# 3.4011973816621555

# %%
#18.Calculate e raised to the power of x using math.exp().

x=5
math.exp(x)
# Out:
# 148.4131591025766

# %%
#19.Find the value of π (pi) and Euler's number (e) from the math module.
import math
print("value of π (pi):", math.pi)
print("Euler's number (e):", math.e)
# Out:
# value of π (pi): 3.141592653589793
# Euler's number (e): 2.718281828459045

# %%
#20.Find the distance between two points using math.dist().
x=(5,8)
y=(8,5)
distance=math.dist(x,y)
print(distance)
# Out:
# 4.242640687119285

# %%
#21.Calculate the hypotenuse of a right triangle using math.hypot().
x=3
y=4
hypot=math.hypot(x,y)
print(hypot)
# Out:
# 5.0

# %%
#22.Find the combination (nCr) using math.comb().
x=5
y=2
math.comb(x,y)
# Out:
# 10

# %%
#23.Find the permutation (nPr) using math.perm().
x=5
y=2
math.perm(x,y)
# Out:
# 20

# %%
#24.Check whether a number is finite, infinite, or NaN using `math.isfinite()`, `math.isinf()`, and `math.isnan()`.
num=-20.526
IF=math.isfinite(num)
INF=math.isinf(num)
NAN=math.isnan(num)
print(IF)
print(INF)
print(NAN)
# Out:
# True
# False
# False

# %%
#25.Find the product of all numbers in a list using `math.prod()`.
num=2,3,4,5,6
math.prod(num)
# Out:
# 720

# %%
#26.Find the sum of square roots of all numbers in a list.

num=(25,16,9,49,4)
square_root=[math.sqrt(n) for n in num]
sum(square_root)
# Out:
# 21.0

# %%
#27.Find the largest integer less than or equal to the square root of a given number.
num = 50
math.floor(math.sqrt(num))
# Out:
# 7

# %%
#28.Calculate compound interest using `math.pow()`.
p= 500
r= .5
n=1
t=3
A= p * math.pow((1 + r/n), n*t)
print("compound interest is :", A - p)
# Out:
# compound interest is : 1187.5

# %%
#29. Find the area and circumference of a circle using `math.pi`.
r= 5
circle_area = math.pi* math.pow(r, 2)
circumference = 2 * math.pi * r
print("area of circle :", circle_area)
print("circumference of circle:", circumference)
# Out:
# area of circle : 78.53981633974483
# circumference of circle: 31.41592653589793

# %%
#30.Create a scientific calculator that supports square root, factorial, logarithm, power, trigonometric functions, GCD, and LCM.

import math

def scientific_calculator():
    print("Scientific Calculator")
    print("Select function:")
    print("Square Root")
    print("Factorial")
    print("Logarithm (base 10)")
    print("Power")
    print("Trigonometric Functions (sin, cos, tan)")
    print("GCD")
    print("LCM")

    choice = int(input("Enter the number (1-7): "))

    if choice == 1:
        num = float(input("Enter the number: "))
        print("Square Root:", math.sqrt(num))

    elif choice == 2:
        num = int(input("Enter the number: "))
        print("Factorial:", math.factorial(num))

    elif choice == 3:
        num = float(input("Enter the number: "))
        print("Logarithm (base 10):", math.log10(num))

    elif choice == 4:
        base = float(input("Enter base value: "))
        exp = float(input("Enter exponent: "))
        print("Power:", math.pow(base, exp))

    elif choice == 5:
        angle = float(input("Enter the angle in degrees: "))
        rad = math.radians(angle)
        print("sin:", math.sin(rad))
        print("cos:", math.cos(rad))
        print("tan:", math.tan(rad))

    elif choice == 6:
        a = int(input("Enter first number: "))
        b = int(input("Enter second number: "))
        print("GCD:", math.gcd(a, b))

    elif choice == 7:
        a = int(input("Enter first number: "))
        b = int(input("Enter second number: "))
        print("LCM:", math.lcm(a, b))

    else:
        print("Invalid option, choose a valid option!")


scientific_calculator()
# Out:
# Scientific Calculator
# Select function:
# Square Root
# Factorial
# Logarithm (base 10)
# Power
# Trigonometric Functions (sin, cos, tan)
# GCD
# LCM
# LCM: 2

# %% [markdown]
#  Python Operators – 30 Coding Questions

# %%
### Arithmetic Operators
#1. Write a program to perform addition, subtraction, multiplication, division, floor division, modulus, and exponentiation on two numbers.
n= int(input ("enter the number: "))
p= int(input ("enter the number: "))    

print("addition of n,p :", n + p )
print("subtraction of n,p :", n- p)
print("multiplication of n , p:",n * p)
print("division of n,p:", n / p)
print("floor division of n,p :", n//p)
print("modulus of n,p:",n % p )
print("exponentiation:", n ** p )
# Out:
# addition of n,p : 11
# subtraction of n,p : -1
# multiplication of n , p: 30
# division of n,p: 0.8333333333333334
# floor division of n,p : 0
# modulus of n,p: 5
# exponentiation: 15625

# %%
#2. Swap two numbers without using a third variable.

n= 3
p= 1
print("n , p :", n , p)

n = n + p
p = n - p
n = n - p


print ("swapped n , p:", n , p)
# Out:
# n , p : 3 1
# swapped n , p: 1 3

# %%
#3. Find whether a number is even or odd using the modulus operator.
num = 25

if num % 2 == 0:
    print(num , "is Even number")
else:
    print(num, "is Odd number")
# Out:
# 25 is Odd number

# %%
# 4. Reverse a three-digit number using arithmetic operators.

num = 183
hundreds = num // 100
tens = (num // 10) % 10
ones = num % 10

reversed_num = ones * 100 + tens * 10 + hundreds
print("reverse of the number 183 is:",reversed_num)
# Out:
# reverse of the number 183 is: 381

# %%
#5. Find the last digit and first digit of a given number.

num = int(input("enter the number"))

last_digit = num % 10
first_digit = num // 100
print("last digit of given number 201 is :" , last_digit)
print("first digit of given number 201  is :" , first_digit)
# Out:
# last digit of given number 201 is : 1
# first digit of given number 201  is : 2

# %% [markdown]
# Assignment Operators

# %%
#6.Demonstrate all assignment operators (=, +=, -=, *=, /=, //=, %= and **=) on a variable.
x = 20
print (x)

x += 2
print("+=:", x)

x -= 5
print("-=:", x)

x *= 4
print("*=:", x)

x /= 5
print("/=:", x)

x //= 6
print("//=:", x)

x %= 7
print("%=:", x)
x **= 10
print ("**=:", x)
# Out:
# 20
# +=: 22
# -=: 17
# *=: 68
# /=: 13.6
# //=: 2.0
# %=: 2.0
# **=: 1024.0

# %%
#7.Update a bank account balance using compound assignment operators.
bank_balance= 500
print("Bank balance:", bank_balance)
bank_balance +=500
print("Added 500 to balance:",bank_balance)
bank_balance  -= 200
print("Deducted 200 from balance:",bank_balance)
bank_balance *= 2
print("After multiplication with 2 :",bank_balance)
bank_balance /= 3
print("After division with 3 :",bank_balance)
bank_balance //= 1.2
print("After floor division:",bank_balance)
bank_balance  %=10
print("After modulus:",bank_balance)
bank_balance **= 5
print("After exponentiation:",bank_balance)
# Out:
# Bank balance: 500
# Added 500 to balance: 1000
# Deducted 200 from balance: 800
# After multiplication with 2 : 1600
# After division with 3 : 533.3333333333334
# After floor division: 444.0
# After modulus: 4.0
# After exponentiation: 1024.0

# %%
#8.Calculate the total marks using += inside a loop.
Praveen_marks = [86,89,96,84,99,91]
total_marks = 0

for  marks in Praveen_marks:
    total_marks += marks
print("Praveen Total marks for 600 :", total_marks)
# Out:
# Praveen Total marks for 600 : 545

# %% [markdown]
# Comparison Operators

# %%
#9.Compare two numbers and print the larger number.
n = 10
p = 20

if n > p :
    print("larger number is :", n)
elif n < p:
    print("larger number is :", p)
else :
    print("no larger number both are same :", n,p)
# Out:
# larger number is : 20

# %%
#10.Check whether three numbers are equal.
x =45
y =50
z =50
if x== y == z:
    print("three numbers are equal")
else:
    print("three numbers are not equal")
# Out:
# three numbers are not equal

# %%
#11.Find the largest among three numbers using comparison operators.
x =45
y =55
z =50
if x > y and x > z:
    print(x, " x is largest number ")
elif y > z and y > x:
    print(y, " y is largest number")
else :
    print(z, " z is largest number")
# Out:
# 55  y is largest number

# %%
#12.Check whether a student is eligible to vote based on age.
age = 19

if age >= 18:
    print(" student is eligible for vote ")
else:
    print("student is not eligible for vote")
# Out:
#  student is eligible for vote

# %% [markdown]
# Logical Operators

# %%
#13.Check if a person is eligible for a loan (age > 21 AND salary > 30000).
age = int(input("enter the age "))
salary = int(input("enter the salary "))

if age > 21 and salary > 30000:
    print("person is eligible for loan")
else:
    print("person is not eligible for loan")
# Out:
# person is eligible for loan

# %%
#14.Check if a number lies between 10 and 100 using logical operators.
num = int(input("enter the number"))
if num >=10 and num <=100:
    print("number lies between 10 and 100")
else:
    print(" number not lies between 10 to 100")
# Out:
# number lies between 10 and 100

# %%
#15.Validate username and password using logical operators.

valid_username = "Praveen"
valid_password = "@2026"

username = input(" enter the username: ")
password = input("enter the password: ")

if username == valid_username and password == valid_password:
    print("Enter into application")
else:
    print("incorrect username or password kindly check")
# Out:
# incorrect username or password kindly check

# %%
#16.Determine whether a year is a leap year using logical conditions.
year = int(input("Enter a year"))

if year % 400 == 0 or year % 4 ==0 and not year % 100==0:
    print("its a leap year ")
else:
    print("its not a leap year")
# Out:
# its a leap year

# %% [markdown]
# Bitwise Operators

# %%
#17.Find the bitwise AND, OR, XOR of two numbers.
x = 10
y = 20

print("AND:",x & y)
print("OR:", x | y)
print("XOR:",x ^ y)
# Out:
# AND: 0
# OR: 30
# XOR: 30

# %%
#18.Perform left shift and right shift operations.

x= int(input("enter the number"))

print("left shift:", x << 1)
print("right shift:", x>> 1)
# Out:
# left shift: 50
# right shift: 12

# %%
#19.Check whether a number is even using a bitwise operator.
num = 26

if num & 1 == 0 :
    print("number is even")
else :
    print("nummber is odd")
# Out:
# number is even

# %%
#20.Swap two numbers using the XOR operator.
x = 10
y = 15

print(x , y)

x= x ^ y
y= x ^ y
x= x ^ y
print(x, y)
# Out:
# 10 15
# 15 10

# %%
#21.Count how many bits are set to 1 in a number using bitwise operations.
num = int(input("enter a number"))
count = 0
while num > 0:
   if num  & 1 :
        count += 1
   num =  num >> 1
print("number of set bits", count)
# Out:
# number of set bits 3

# %% [markdown]
# Identity Operators

# %%
#22.Demonstrate the difference between is and ==.
x = (10,10)
y = (10,10)
print(x == y)
print(x is y)

x = 10
y = 10
print(x == y)
print(x is y)
# Out:
# True
# False
# True
# True

# %%
#23.Check whether two variables refer to the same list object.
list_A = [7,5,3]
list_B = [9,5,1]
list_C = list_A
print("refer to the same list object :", list_A is list_B)
print("refer to the same list object :",list_A is list_C)
# Out:
# refer to the same list object : False
# refer to the same list object : True

# %%
#24.Show the behavior of is not with integers and lists.
x = 5
y = 5
z = 6
print("x is not y:", x is not y)
print("x is not z :",x is not z)

list_A = [7,5,3]
list_B = [9,5,1]
list_C = list_A
print("A is not B :",list_A is not list_B)
print("A is not C:",list_A is not list_C)
# Out:
# x is not y: False
# x is not z : True
# A is not B : True
# A is not C: False

# %% [markdown]
# Membership Operators

# %%
#25.Check whether a character exists in a string.
name ="praveen"
print("v in name :","v" in name)
print("n in name:","n" in name)
print("x not in name :","x" not in name)
# Out:
# v in name : True
# n in name: True
# x not in name : True

# %%
#26.Check whether a number exists in a list.
list = [20,30,40,50]

print("40 in list :",40 in list)
print("60 not in list:", 60 not in list)
print("50 in list :", 50 in list)
# Out:
# 40 in list : True
# 60 not in list: True
# 50 in list : True

# %%
#27.Count how many vowels in a string belong to a predefined vowel list using in.
text = 'entrepreneur'
vowels = "aeiou"
count = 0

for ch in text:
    if ch in vowels:
        count += 1
print("count of vowels in string:", count)
# Out:
# count of vowels in string: 5

# %% [markdown]
# Mixed Operator Programs

# %%
#28.Build a simple calculator using arithmetic and comparison operators.
n= int(input ("enter the number: "))
p= int(input ("enter the number: "))    

print("addition of n,p :", n + p )
print("subtraction of n,p :", n- p)
print("multiplication of n , p:",n * p)
print("division of n,p:", n / p)
print("floor division of n,p :", n//p)
print("modulus of n,p:",n % p )
print("exponentiation:", n ** p )

print("n==p:" , n == p)
print("n !=p", n != p)
print("n>p:", n > p)
print("n<p:", n < p)
print("n>=p:", n >= p)
print("n<=p:", n <= p)
# Out:
# addition of n,p : 30
# subtraction of n,p : -10
# multiplication of n , p: 200
# division of n,p: 0.5
# floor division of a,b : 0
# modulus of n,p: 10
# exponentiation: 100000000000000000000
# n==p: False
# n !=p True
# n>p: False
# n<p: True
# n>=p: False
# n<=p: True

# %%
#29.Create a grading system using comparison and logical operators.
marks = 96
if marks >=90 and marks <=100:
    grade = "A"
elif marks >=80 and marks <90:
    grade = "B"
elif marks >=65 and marks <80:
    grade = "C"
elif marks >=35 and marks <65:
    grade = "D"
else:
    grade = "Fail"

print("Marks :", marks)
print("Grade :", grade)
# Out:
# Marks : 96
# Grade : A

# %%
#30.Build a menu-driven calculator that uses arithmetic, comparison, logical, assignment, membership, identity, and bitwise operators wherever applicable.

num1=int(input("Enter the given number:"))
num2=int(input("Enter the given number:"))
while True:
  print("==========Menu========")
  print("1.Artimetic operations:")
  print("2.Comparison operations:")
  print("3.Logical operations:")
  print("4.Assignment operations:")
  print("5.Membership operations:")
  print("6.Identity operations:")
  print("7.Bitwise operations:")
  print("8.Exit")
  choice=int(input("Enter the given number:"))
  if choice==1:
    print("Arithmetic operators:")
    print("1.Addition: ",num1+num2)
    print("2.Subtraction: ",num1-num2)
    print("3:Multiplication: " ,num1*num2)
    print("4.Division: ",num1/num2)
    print("5.Floor Division: ",num1//num2)
    print("6.Modulus: ",num1%num2)
    print("7.Exponentiation: ",num1**num)
  elif choice==2:
    print("Comparison operators")
    print("num1==num2:" ,num1==num2)
    print("num1!=num2:" ,num1!=num2)
    print("num1>num2:" ,num1>num2)
    print("num1<num2:" ,num1<num2)
    print("num1>=num2:" ,num1>=num2)
    print("num1<=num2:" ,num1<=num2)
  elif choice==3:
    print("Logical opertors")
    print("num1>0 and num2>0: ",num1>0 and num2>0)
    print("num1>0 or num2>0: ",num1>0 or num2>0)
    print("not(num1>0):", not(num1>0))
  elif choice==4:
    print("Assignment operators")
    x=num1
    print(x)
    x+=num2
    print(x)
    x-=num2
    print(x)
    x*=num2
    print(x)
    x/=num2
    print(x)
    x//=num2
    print(x)
    x%=num2
    print(x)
    x**=num2
    print(x)
  elif choice==5:
    print("Membership operators")
    numbers=[10,20,30,40,50]
    print("List:",numbers)
    print("a is in list:" ,a in numbers)
    print("bis not in List:" ,b not in numbers)
  elif choice==6:
    print("Identity operators")
    print("num1 is num2:" ,num1 is num2)
    print("num1 is not num2:" ,num1 is not num2)
  elif choice==7:
    print("Bitwise operators")
    print("num1&num2:",num1&num2)
    print("num1|num2:",num1|num2)
    print("num1^num2:",num1^num2)
  elif choice==8:
    print(exit)
    break
  else:
    print("Invalid")
# Out:
# ==========Menu========
# 1.Artimetic operations:
# 2.Comparison operations:
# 3.Logical operations:
# 4.Assignment operations:
# 5.Membership operations:
# 6.Identity operations:
# 7.Bitwise operations:
# 8.Exit
# Bitwise operators
# num1&num2: 0
# num1|num2: 15
# num1^num2: 15
# ==========Menu========
# 1.Artimetic operations:
# 2.Comparison operations:
# 3.Logical operations:
# 4.Assignment operations:
# 5.Membership operations:
# 6.Identity operations:
# 7.Bitwise operations:
# 8.Exit
# <IPython.core.autocall.ZMQExitAutocall object at 0x000001BF3E57B0E0>
